# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# display all columns of the dataframe
pd.options.display.max_columns = None
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset - Original Raw data

# %%
df=pd.read_csv(r'C:\Users\SACHIN\Desktop\CAPSTONE PROJECT\Official Capstone diabetes Project\Data set CSV\dataset_diabetes UCI\diabetic_data.csv')
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# ...

# %%
#droping not useful variables
df.drop(['encounter_id','patient_nbr'],axis=1,inplace=True)

# %%
df.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)      ?                  6
# 1        Caucasian  Female  [10-20)      ?                  1
# 2  AfricanAmerican  Female  [20-30)      ?                  1
# 3        Caucasian    Male  [30-40)      ?                  1
# 4        Caucasian    Male  [40-50)      ?                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1          ?
# 1                         1                    7                 3          ?
# 2                         1                    7                 2          ?
# 3                         1                    7                 2          ?
# 4                         1                    7                 1          ?
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
plt.rcParams['figure.figsize'] = (8, 5)

# %% [markdown]
# # Univariate

# %% [markdown]
# - Race

# %%
df.race.value_counts()
# Out:
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: race, dtype: int64

# %% [markdown]
# - Caucasian : NORTH AMERICAN
# - Hispanic  : a Spanish-speaking person

# %%
sns.countplot(df.race)
plt.show()

# %% [markdown]
# - Gender

# %%
df.gender.value_counts()
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
sns.countplot(df.gender)
plt.show()

# %%
df['gender']=df['gender'].replace('Unknown/Invalid',np.nan)
df['gender'].dropna(inplace=True)

# %%
df['gender'].value_counts()
# Out:
# Female    54708
# Male      47055
# Name: gender, dtype: int64

# %%
df['gender'] = df['gender'].replace({'Female' : 0, 'Male' : 1})

# %%
sns.countplot(df.gender)
plt.show()

# %% [markdown]
# - Age

# %%
df.age.value_counts()
# Out:
# [70-80)     26068
# [60-70)     22483
# [50-60)     17256
# [80-90)     17197
# [40-50)      9685
# [30-40)      3775
# [90-100)     2793
# [20-30)      1657
# [10-20)       691
# [0-10)        161
# Name: age, dtype: int64

# %%
sns.countplot(df.age,palette='Set2')
plt.show()

# %% [markdown]
# - Readmitted

# %%
df['readmitted'].value_counts()
# Out:
# NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64

# %%
sns.countplot(df.readmitted)
plt.show()

# %%
#readmission converting multiclass to binary class
df['readmitted'] = df['readmitted'].replace({'>30' : 0, 'NO' : 0, '<30' : 1})

# %%
df['readmitted'].value_counts()
# Out:
# 0    90409
# 1    11357
# Name: readmitted, dtype: int64

# %% [markdown]
# - Our target variable is imbalance. Number of readmitted patient are quite less as compared to Not readmitted

# %%
sns.countplot(df.readmitted)
plt.show()

# %% [markdown]
# - time_in_hospital

# %%
df.time_in_hospital.value_counts()
# Out:
# 3     17756
# 2     17224
# 1     14208
# 4     13924
# 5      9966
# 6      7539
# 7      5859
# 8      4391
# 9      3002
# 10     2342
# 11     1855
# 12     1448
# 13     1210
# 14     1042
# Name: time_in_hospital, dtype: int64

# %%
sns.countplot(df.time_in_hospital)
plt.show()

# %% [markdown]
# - num_lab_procedures

# %%
df.num_lab_procedures.unique()
# Out:
# array([ 41,  59,  11,  44,  51,  31,  70,  73,  68,  33,  47,  62,  60,
#         55,  49,  75,  45,  29,  35,  42,  66,  36,  19,  64,  25,  53,
#         52,  87,  27,  37,  46,  28,  48,  72,  10,   2,  65,  67,  40,
#         54,  58,  57,  43,  32,  83,  34,  39,  69,  38,  56,  22,  96,
#         78,  61,  88,  50,   1,  18,  82,   9,  63,  24,  71,  77,  81,
#         76,  90,  93,   3, 103,  13,  80,  85,  16,  15,  12,  30,  23,
#         17,  21,  79,  26,   5,  95,  97,  84,  14,  74, 105,  86,  98,
#         20,   6,  94,   8, 102, 100,   7,  89,  91,  92,   4, 101,  99,
#        114, 113, 111, 129, 107, 108, 106, 104, 109, 120, 132, 121, 126,
#        118], dtype=int64)

# %%
sns.distplot(df.num_lab_procedures,color='navy',bins=80)
plt.show()

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %% [markdown]
# - num_procedures

# %%
df.num_procedures.value_counts()
# Out:
# 0    46652
# 1    20742
# 2    12717
# 3     9443
# 6     4954
# 4     4180
# 5     3078
# Name: num_procedures, dtype: int64

# %%
sns.countplot(df.num_procedures)
plt.show()

# %%
sns.countplot(df.num_procedures, hue = df['readmitted']).set_title('num_preocedure VS. Readmission')
plt.show()

# %% [markdown]
# - num_medications

# %%
df.num_medications.max()
# Out:
# 81

# %%
df.num_medications.min()
# Out:
# 1

# %%
sns.countplot(df.num_medications)
plt.xticks()
plt.show()

# %% [markdown]
# - number_outpatient

# %%
df.number_outpatient.value_counts()
# Out:
# 0     85027
# 1      8547
# 2      3594
# 3      2042
# 4      1099
# 5       533
# 6       303
# 7       155
# 8        98
# 9        83
# 10       57
# 11       42
# 13       31
# 12       30
# 14       28
# 15       20
# 16       15
# 17        8
# 20        7
# 21        7
# 18        5
# 22        5
# 24        3
# 27        3
# 19        3
# 25        2
# 26        2
# 23        2
# 29        2
# 33        2
# 35        2
# 36        2
# 28        1
# 34        1
# 37        1
# 38        1
# 39        1
# 40        1
# 42        1
# Name: number_outpatient, dtype: int64

# %%
sns.countplot(df.number_outpatient)
plt.xticks()
plt.show()

# %% [markdown]
# - number_emergency

# %%
df.number_emergency.value_counts()
# Out:
# 0     90383
# 1      7677
# 2      2042
# 3       725
# 4       374
# 5       192
# 6        94
# 7        73
# 8        50
# 10       34
# 9        33
# 11       23
# 13       12
# 12       10
# 22        6
# 18        5
# 16        5
# 20        4
# 19        4
# 14        3
# 15        3
# 21        2
# 25        2
# 64        1
# 76        1
# 24        1
# 28        1
# 29        1
# 37        1
# 42        1
# 46        1
# 54        1
# 63        1
# Name: number_emergency, dtype: int64

# %% [markdown]
# - number_diagnoses

# %%
df.number_diagnoses.value_counts()
# Out:
# 9     49474
# 5     11393
# 8     10616
# 7     10393
# 6     10161
# 4      5537
# 3      2835
# 2      1023
# 1       219
# 16       45
# 10       17
# 13       16
# 11       11
# 15       10
# 12        9
# 14        7
# Name: number_diagnoses, dtype: int64

# %%
sns.countplot(df.number_diagnoses)
plt.show()

# %% [markdown]
# - 23 medicine columns :

# %%
drug=['metformin',
 'repaglinide',
 'nateglinide',
 'chlorpropamide',
 'glimepiride',
 'acetohexamide',
 'glipizide',
 'glyburide',
 'tolbutamide',
 'pioglitazone',
 'rosiglitazone',
 'acarbose',
 'miglitol',
 'troglitazone',
 'tolazamide',
 'examide',
 'citoglipton',
 'insulin',
 'glyburide-metformin',
 'glipizide-metformin',
 'glimepiride-pioglitazone',
 'metformin-rosiglitazone',
 'metformin-pioglitazone']

# %%
for i in drug:
    print(i,df[i].unique())
    print(df[i].value_counts())
# Out:
# metformin ['No' 'Steady' 'Up' 'Down']
# No        81778
# Steady    18346
# Up         1067
# Down        575
# Name: metformin, dtype: int64
# repaglinide ['No' 'Up' 'Steady' 'Down']
# No        100227
# Steady      1384
# Up           110
# Down          45
# Name: repaglinide, dtype: int64
# nateglinide ['No' 'Steady' 'Down' 'Up']
# No        101063
# Steady       668
# Up            24
# Down          11
# Name: nateglinide, dtype: int64
# chlorpropamide ['No' 'Steady' 'Down' 'Up']
# No        101680
# Steady        79
# Up             6
# Down           1
# Name: chlorpropamide, dtype: int64
# glimepiride ['No' 'Steady' 'Down' 'Up']
# No        96575
# Steady     4670
# Up          327
# Down        194
# Name: glimepiride, dtype: int64
# acetohexamide ['No' 'Steady']
# No        101765
# Steady         1
# Name: acetohexamide, dtype: int64
# glipizide ['No' 'Steady' 'Up' 'Down']
# No        89080
# Steady    11356
# Up          770
# Down        560
# ...

# %%
for i in drug:
    print(i,sns.countplot(df[i]))
    plt.show()
# Out:
# metformin AxesSubplot(0.125,0.125;0.775x0.755)
# repaglinide AxesSubplot(0.125,0.125;0.775x0.755)
# nateglinide AxesSubplot(0.125,0.125;0.775x0.755)
# chlorpropamide AxesSubplot(0.125,0.125;0.775x0.755)
# glimepiride AxesSubplot(0.125,0.125;0.775x0.755)
# acetohexamide AxesSubplot(0.125,0.125;0.775x0.755)
# glipizide AxesSubplot(0.125,0.125;0.775x0.755)
# glyburide AxesSubplot(0.125,0.125;0.775x0.755)
# tolbutamide AxesSubplot(0.125,0.125;0.775x0.755)
# pioglitazone AxesSubplot(0.125,0.125;0.775x0.755)
# rosiglitazone AxesSubplot(0.125,0.125;0.775x0.755)
# acarbose AxesSubplot(0.125,0.125;0.775x0.755)
# miglitol AxesSubplot(0.125,0.125;0.775x0.755)
# troglitazone AxesSubplot(0.125,0.125;0.775x0.755)
# tolazamide AxesSubplot(0.125,0.125;0.775x0.755)
# examide AxesSubplot(0.125,0.125;0.775x0.755)
# citoglipton AxesSubplot(0.125,0.125;0.775x0.755)
# insulin AxesSubplot(0.125,0.125;0.775x0.755)
# glyburide-metformin AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# - max_glu_serum

# %%
df.max_glu_serum.value_counts()
# Out:
# None    96420
# Norm     2597
# >200     1485
# >300     1264
# Name: max_glu_serum, dtype: int64

# %%
sns.countplot(df.max_glu_serum)
plt.show()

# %% [markdown]
# - It indicates the range of the result or if the test was not taken. Values: “>200,” “>300,” “normal,” and “none” if not measured
# - We also reducing Glucose serum test result into categories of Normal(1), Abnormal(2) and Not tested(0)

# %%
df.max_glu_serum.replace({'>200':2,'>300':2,'Norm':1,'None':0},inplace=True)

# %%
df.max_glu_serum.value_counts()
# Out:
# 0    96420
# 2     2749
# 1     2597
# Name: max_glu_serum, dtype: int64

# %%
sns.countplot(df.max_glu_serum)
plt.show()

# %% [markdown]
# - A1Cresult

# %%
df.A1Cresult.value_counts()
# Out:
# None    84748
# >8       8216
# Norm     4990
# >7       3812
# Name: A1Cresult, dtype: int64

# %%
sns.countplot(df.A1Cresult)
plt.show()

# %% [markdown]
# - A normal A1C level is below 5.7%, a level of 5.7% to 6.4% indicates prediabetes, and a level of 6.5% or more indicates diabetes. Within the 5.7% to 6.4% prediabetes range, the higher your A1C, the greater your risk is for developing type 2 diabetes.

# %%
df["A1Cresult"] = df["A1Cresult"].replace({"None":0,"Norm":1,">7":2,">8":2})

# %%
sns.countplot(df.A1Cresult)
plt.show()

# %% [markdown]
# - change

# %%
df.change.value_counts()
# Out:
# No    54755
# Ch    47011
# Name: change, dtype: int64

# %%
sns.countplot(df.change)
plt.show()

# %% [markdown]
# - diabetesMed

# %%
df.diabetesMed.value_counts()
# Out:
# Yes    78363
# No     23403
# Name: diabetesMed, dtype: int64

# %%
sns.countplot(df.diabetesMed)
plt.show()

# %% [markdown]
# # Bivariate

# %%
sns.countplot(df['diabetesMed'], hue = df['readmitted']).set_title('gender VS. Readmission')
# Out:
# Text(0.5, 1.0, 'gender VS. Readmission')

# %% [markdown]
# - gender and readmitted

# %%
sns.countplot(y= df['gender'], hue = df['readmitted']).set_title('gender VS. Readmission')
plt.show()

# %% [markdown]
# - age and readmitted

# %%
sns.countplot(x= df['age'], hue = df['readmitted']).set_title('Age of Patient VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Age of Patient VS. Readmission')

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %% [markdown]
# - Age and gender

# %%
sns.countplot(x= df['age'], hue = df['gender'],palette='Paired').set_title('Age of Patient VS. Gender')
# Out:
# Text(0.5, 1.0, 'Age of Patient VS. Gender')

# %% [markdown]
# - race and readmitted

# %%
sns.countplot(x = df['race'], hue = df['readmitted'])
plt.show()

# %%
df['race'] = df['race'].replace('?',np.nan)

# %%
df['race'] = df['race'].fillna(df['race'].mode()[0]) #replacing with mode

# %%
sns.countplot(x = df['race'], hue = df['readmitted'],palette='Set1')
plt.show()

# %% [markdown]
# - time_in_hospital and readmitted

# %%
sns.countplot(x = df['time_in_hospital'], hue = df['readmitted'],palette='Set2').set_title('time_in_hospital VS. readmitted')
plt.show()

# %% [markdown]
# - change and readmitted

# %%
sns.countplot(df['change'], hue = df['readmitted'],palette='Set2').set_title('Change of Medication VS. Readmission')
plt.show()

# %% [markdown]
# - diabetesMed and readmitted

# %%
sns.countplot(df['diabetesMed'], hue = df['readmitted']).set_title('Diabetes Medication prescribed VS Readmission')
# Out:
# Text(0.5, 1.0, 'Diabetes Medication prescribed VS Readmission')

# %% [markdown]
# - Service Utilization and Readmission

# %%
df['service_utilization'] = df['number_outpatient'] + df['number_emergency'] + df['number_inpatient'] #year_visits

# %%
df.drop(['number_outpatient','number_emergency','number_inpatient'],axis=1,inplace=True)

# %%
sns.barplot( y = df['service_utilization'], x = df['readmitted']).set_title('Service Utilization VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Service Utilization VS. Readmission')

# %% [markdown]
# - max_glu_serum and readmitted

# %%
sns.countplot(x = df['max_glu_serum'], hue = df['readmitted'],palette='rocket').set_title('Glucose test serum test result VS. Readmission')
plt.show()

# %% [markdown]
# - A1Cresult and readmitted

# %%
sns.countplot(x= df['A1Cresult'], hue = df['readmitted'],palette='Set2').set_title('A1C test result VS. Readmission')
# Out:
# Text(0.5, 1.0, 'A1C test result VS. Readmission')

# %% [markdown]
# - Insulin and readmitted

# %%
sns.countplot(x= df['insulin'], hue = df['readmitted'],palette='Set2').set_title('Insulin VS. Readmission')
# Out:
# Text(0.5, 1.0, 'Insulin VS. Readmission')

# %%
sns.countplot(x= df['metformin'], hue = df['readmitted'],palette='Paired').set_title('metformin VS. Readmission')
plt.show()

# %% [markdown]
# - glipizide and readmitted

# %%
sns.countplot(x= df['glipizide'], hue = df['readmitted'],palette='Set1').set_title('glipizide VS. Readmission')
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted',
#        'service_utilization'],
#       dtype='object')

# %% [markdown]
# - num_medications and readmitted

# %%
sns.countplot(x= df['num_medications'], hue = df['readmitted'],palette='Set1').set_title('num_medications VS. Readmission')
plt.xticks()
plt.show()

# %% [markdown]
# - 'diag_1','diag_2','diag_3' and readmitted

# %% [markdown]
# - Diabetes:0
# - Circulatory:1
# - Respiratory:2
# - Digestive:3
# - Injury:4
# - Musculoskelet:5
# - Genitourinory:6
# - Neoplasms:7
# - Others:8

# %%
df.replace('?',np.nan,inplace=True)

# %%
df.loc[df['diag_1'].str.contains('V',na=False),['diag_1']]=8 #Others
df.loc[df['diag_1'].str.contains('E',na=False),['diag_1']]=8
df.loc[df['diag_2'].str.contains('V',na=False),['diag_2']]=8
df.loc[df['diag_2'].str.contains('E',na=False),['diag_2']]=8
df.loc[df['diag_3'].str.contains('V',na=False),['diag_3']]=8
df.loc[df['diag_3'].str.contains('E',na=False),['diag_3']]=8

# %%
df['diag_1']=df['diag_1'].astype('float')
df['diag_2']=df['diag_2'].astype('float')
df['diag_3']=df['diag_3'].astype('float')

# %%
for j in ['diag_1','diag_2','diag_3']:
    for i in range(0,len(df)):
        if (np.floor(df.loc[i,j]) == 250):
            df.loc[i, j] = 0 #Diabetes
        elif (df.loc[i, j] >= 390 and df.loc[i, j] < 460) or (np.floor(df.loc[i,j]) == 785):
            df.loc[i, j] = 1 #Circulatory
        elif (df.loc[i, j] >= 460 and df.loc[i, j] < 520) or (np.floor(df.loc[i,j]) == 786):
            df.loc[i, j] = 2 #Respiratory
        elif (df.loc[i, j] >= 520 and df.loc[i, j] < 580) or (np.floor(df.loc[i,j]) == 787):
            df.loc[i, j] = 3 #Digestive
        elif (df.loc[i, j] >= 800 and df.loc[i, j] < 1000):
            df.loc[i, j] = 4 #Injury
        elif (df.loc[i, j] >= 710 and df.loc[i, j] < 740):
            df.loc[i, j] = 5 #Musculoskelet
        elif (df.loc[i, j] >= 580 and df.loc[i, j] < 630) or (np.floor(df.loc[i,j]) == 788):
            df.loc[i, j] = 6 #Genitourinory
        elif (df.loc[i, j] >= 140 and df.loc[i, j] < 240):
            df.loc[i, j] = 7 #Neoplasms
        else:
            df.loc[i, j] = 8 #Others
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-63a0e5fb6781> in <module>
#       2     for i in range(0,len(df)):
#       3         if (np.floor(df.loc[i,j]) == 250):
# ----> 4             df.loc[i, j] = 0 #Diabetes
#       5         elif (df.loc[i, j] >= 390 and df.loc[i, j] < 460) or (np.floor(df.loc[i,j]) == 785):
#       6             df.loc[i, j] = 1 #Circulatory
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
# ...

# %%
df['diag_1']=df['diag_1'].astype('int')
df['diag_2']=df['diag_2'].astype('int')
df['diag_3']=df['diag_3'].astype('int')

# %%
for i in ['diag_1','diag_2','diag_3']:
    print(df[i].unique())

# %%
diag=['diag_1','diag_2','diag_3']
for i in diag:
    print(i,sns.countplot(df[i],hue = df['readmitted'],palette='Set1'))
    plt.show()

# %%
num = df.select_dtypes(include=np.number)

# %%
for i in num:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# # END

# %%
plt.pie(df['gender'],autopct='%1.1f%%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-331e4de43fb9> in <module>
# ----> 1 plt.pie(df['gender'],autopct='%1.1f%%')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3011         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    3012         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
# -> 3013         **({"data": data} if data is not None else {}))
#    3014
#    3015
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...
